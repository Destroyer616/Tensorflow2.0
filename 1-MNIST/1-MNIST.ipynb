# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=data.load_data()

# %%
 class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=["accuracy"])

# %%
model.fit(train_images,train_labels,epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.5055 - acc: 0.8223
# Epoch 2/10
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.3808 - acc: 0.8623
# Epoch 3/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.3433 - acc: 0.8749
# Epoch 4/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.3209 - acc: 0.8821
# Epoch 5/10
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.3017 - acc: 0.8882
# Epoch 6/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2846 - acc: 0.8948
# Epoch 7/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2716 - acc: 0.8982
# Epoch 8/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2627 - acc: 0.9011
# Epoch 9/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2513 - acc: 0.9065
# Epoch 10/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2422 - acc: 0.9095

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels)
print('Tested Acc :',test_acc)
# Out:
# 10000/10000 [==============================] - 0s 41us/sample - loss: 0.3292 - acc: 0.8862
# Tested Acc : 0.8862

# %%
prediction = model.predict(test_images)

# %%
for i in range(6):
    plt.grid(False)
    plt.imshow(test_images[i],cmap=plt.cm.binary)
    plt.xlabel("Actual: " + class_names[test_labels[i]])
    plt.title("Prediction " + class_names[np.argmax(prediction[i])])
    plt.show()

# %%
model.save('MNISTmodel.h5')
